# %%
class Node:
  def __init__(self,x):
    self.data = x
    self.next = None
class Stack:
  def __init__(self):
    self.top = None
  def push(self):
    x = int(input("Enter the element you want to add"))
    new_node = Node(x)
    if self.top is None:
      self.top = new_node
      self.top.next = None
    else:
      new_node.next = self.top
      self.top = new_node
  def pop(self):
    if self.top is None:
      print("Stack is Empty")
    elif self.top.next is None:
      print("Popped element is : ", self.top.data)
      print("---------")
      self.top.next = None
    else:
      print("Popped element : ", self.top.data)
      print("---------")
      temp = self.top
      self.top = temp.next
      temp.next = None
  def display(self):
    if self.top is None:
      print("Stack is empty")
      print("--------")
    else:
      print("Elements of the stack are : ")
      temp = self.top
      while temp:
        print(temp.data)
        temp = temp.next
      print("Top element of the stack is ", self.top.data)
      print("-------")
stack1 = Stack()
while(1):
  print("Enter the option from below : ")
  print("1. Push Operation\n2. Pop OPeration\n 3.Display")
  option = int(input())
  if(option == 1):
    print("Push Operation")
    print("---------")
    stack1.push()
  elif option == 2:
    print("Pop Operation")
    print("---------")
    stack1.pop()
  elif(option == 3):
    print("Display Opeartion")
    print("---------")
    stack1.display()
  else:
    break
# Out:
# Enter the option from below :
# 1. Push Operation
# 2. Pop OPeration
#  3.Display
# 1
# Push Operation
# ---------
# Enter the element you want to add10
# Enter the option from below :
# 1. Push Operation
# 2. Pop OPeration
#  3.Display
# 1
# Push Operation
# ---------
# Enter the element you want to add20
# Enter the option from below :
# 1. Push Operation
# 2. Pop OPeration
#  3.Display
# 1
# Push Operation
# ---------
# Enter the element you want to add30
# Enter the option from below :
# 1. Push Operation
# 2. Pop OPeration
#  3.Display
# 1
# Push Operation
# ---------
# Enter the element you want to add40
# Enter the option from below :
# 1. Push Operation
# 2. Pop OPeration
#  3.Display
# 2
# Pop Operation
# ---------
# Popped element :  40
# ---------
# Enter the option from below :
# 1. Push Operation
# 2. Pop OPeration
#  3.Display
# 3
# Display Opeartion
# ---------
# Elements of the stack are :
# 30
# 20
# 10
# Top element of the stack is  30
# -------
# ...

# %%
# If character is operand add to the postfix operation
# If the character is operator check whether the
